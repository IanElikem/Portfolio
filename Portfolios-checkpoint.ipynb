# %% [markdown]
# # DATA EXPLORATION WITH PANDAS

# %%
#import pandas
import pandas as pd

# %%
#read_csv
worldpopulation=pd.read_csv(r"C:\Users\Kofi Afele\Downloads\WorldPopulation\World Population Live Dataset.csv")
worldpopulation
# Out:
#     CCA3              Name     2022     2020     2015     2010     2000  \
# 0     CN             China  1425887  1424930  1393715  1348191  1264099
# 1     IN             India  1417173  1396387  1322867  1240614  1059634
# 2     US     United States   338290   335942   324608   311183   282399
# 3     ID         Indonesia   275501   271858   259092   244016   214072
# 4     PK          Pakistan   235825   227197   210969   194454   154370
# ..   ...               ...      ...      ...      ...      ...      ...
# 229   MS        Montserrat        4        5        5        5        5
# 230   FK  Falkland Islands        4        4        3        3        3
# 231   NU              Niue        2        2        2        2        2
# 232   TK           Tokelau        2        2        1        1        2
# 233   VA      Vatican City        1        1        1        1        1
#
#         1990    1980    1970  Area (km²)  Density (per km²)  GrowthRate  \
# ...

# %%
#datafram information
worldpopulation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CCA3                         233 non-null    object
#  1   Name                         234 non-null    object
#  2   2022                         234 non-null    int64
#  3   2020                         234 non-null    int64
#  4   2015                         234 non-null    int64
#  5   2010                         234 non-null    int64
#  6   2000                         234 non-null    int64
#  7   1990                         234 non-null    int64
#  8   1980                         234 non-null    int64
#  9   1970                         234 non-null    int64
#  10  Area (km²)                   234 non-null    int64
#  11  Density (per km²)            234 non-null    float64
#  12  GrowthRate                   234 non-null    float64
# ...

# %%
#top 5 rows & columns of the dataframe
worldpopulation.head()
# Out:
#   CCA3           Name     2022     2020     2015     2010     2000     1990  \
# 0   CN          China  1425887  1424930  1393715  1348191  1264099  1153704
# 1   IN          India  1417173  1396387  1322867  1240614  1059634   870452
# 2   US  United States   338290   335942   324608   311183   282399   248084
# 3   ID      Indonesia   275501   271858   259092   244016   214072   182160
# 4   PK       Pakistan   235825   227197   210969   194454   154370   115414
#
#      1980    1970  Area (km²)  Density (per km²)  GrowthRate  \
# 0  982372  822534     9706961           146.8933        1.00
# 1  696828  557501     3287590           431.0675        1.01
# 2  223140  200328     9372610            36.0935        1.00
# 3  148177  115228     1904569           144.6529        1.01
# 4   80624   59291      881912           267.4018        1.02
#
#   World Population Percentage  Rank
# 0                      17.88%     1
# 1                      17.77%     2
# ...

# %%
#last 5 rows & columns of the dataframe
worldpopulation.tail()
# Out:
#     CCA3              Name  2022  2020  2015  2010  2000  1990  1980  1970  \
# 229   MS        Montserrat     4     5     5     5     5    11    11    11
# 230   FK  Falkland Islands     4     4     3     3     3     2     2     2
# 231   NU              Niue     2     2     2     2     2     3     4     5
# 232   TK           Tokelau     2     2     1     1     2     2     2     2
# 233   VA      Vatican City     1     1     1     1     1     1     1     1
#
#      Area (km²)  Density (per km²)  GrowthRate World Population Percentage  \
# 229         102            43.0392        0.99                       0.00%
# 230       12173             0.3105        1.00                       0.00%
# 231         260             7.4385        1.00                       0.00%
# 232          12           155.9167        1.01                       0.00%
# 233           1           510.0000        1.00                       0.00%
#
#      Rank
# 229   230
# 230   231
# 231   232
# 232   233
# ...

# %%
# Selecting columns '.'method
worldpopulation.Name
# Out:
# 0                 China
# 1                 India
# 2         United States
# 3             Indonesia
# 4              Pakistan
#              ...
# 229          Montserrat
# 230    Falkland Islands
# 231                Niue
# 232             Tokelau
# 233        Vatican City
# Name: Name, Length: 234, dtype: object

# %%
# Selecting columns '[]'method
worldpopulation['Area (km²)']
# Out:
# 0      9706961
# 1      3287590
# 2      9372610
# 3      1904569
# 4       881912
#         ...
# 229        102
# 230      12173
# 231        260
# 232         12
# 233          1
# Name: Area (km²), Length: 234, dtype: int64

# %%
#Data cleaning
#.drop_duplicates() drops any dupliactes present in the dataframe
worldpopulation.drop_duplicates()
# Out:
#     CCA3              Name     2022     2020     2015     2010     2000  \
# 0     CN             China  1425887  1424930  1393715  1348191  1264099
# 1     IN             India  1417173  1396387  1322867  1240614  1059634
# 2     US     United States   338290   335942   324608   311183   282399
# 3     ID         Indonesia   275501   271858   259092   244016   214072
# 4     PK          Pakistan   235825   227197   210969   194454   154370
# ..   ...               ...      ...      ...      ...      ...      ...
# 229   MS        Montserrat        4        5        5        5        5
# 230   FK  Falkland Islands        4        4        3        3        3
# 231   NU              Niue        2        2        2        2        2
# 232   TK           Tokelau        2        2        1        1        2
# 233   VA      Vatican City        1        1        1        1        1
#
#         1990    1980    1970  Area (km²)  Density (per km²)  GrowthRate  \
# ...

# %%
#.dropna() removes missing values in the dataframe
worldpopulation.dropna()
# Out:
#     CCA3              Name     2022     2020     2015     2010     2000  \
# 0     CN             China  1425887  1424930  1393715  1348191  1264099
# 1     IN             India  1417173  1396387  1322867  1240614  1059634
# 2     US     United States   338290   335942   324608   311183   282399
# 3     ID         Indonesia   275501   271858   259092   244016   214072
# 4     PK          Pakistan   235825   227197   210969   194454   154370
# ..   ...               ...      ...      ...      ...      ...      ...
# 229   MS        Montserrat        4        5        5        5        5
# 230   FK  Falkland Islands        4        4        3        3        3
# 231   NU              Niue        2        2        2        2        2
# 232   TK           Tokelau        2        2        1        1        2
# 233   VA      Vatican City        1        1        1        1        1
#
#         1990    1980    1970  Area (km²)  Density (per km²)  GrowthRate  \
# ...

# %%
#selecting a row with '.loc[]'
worldpopulation.loc[100]
# Out:
# CCA3                                    CH
# Name                           Switzerland
# 2022                                  8740
# 2020                                  8639
# 2015                                  8282
# 2010                                  7822
# 2000                                  7182
# 1990                                  6712
# 1980                                  6319
# 1970                                  6181
# Area (km²)                           41284
# Density (per km²)                 211.7157
# GrowthRate                            1.01
# World Population Percentage          0.11%
# Rank                                   101
# Name: 100, dtype: object

# %% [markdown]
# # Filtering Columns and Rows

# %%
#filtering based on columns using comparison functions
worldpopulation[worldpopulation['GrowthRate']==1]
# Out:
#     CCA3                       Name     2022     2020     2015     2010  \
# 0     CN                      China  1425887  1424930  1393715  1348191
# 2     US              United States   338290   335942   324608   311183
# 6     BR                     Brazil   215313   213196   205188   196353
# 8     RU                     Russia   144713   145617   144668   143243
# 18    DE                    Germany    83370    83329    82073    81325
# ..   ...                        ...      ...      ...      ...      ...
# 225   WF          Wallis and Futuna       12       12       12       13
# 228   PM  Saint Pierre and Miquelon        6        6        6        6
# 230   FK           Falkland Islands        4        4        3        3
# 231   NU                       Niue        2        2        2        2
# 233   VA               Vatican City        1        1        1        1
#
#         2000     1990    1980    1970  Area (km²)  Density (per km²)  \
# ...

# %%
#filtering based on columns using .isin method
specific_countries=['China','Falkland Islands']
worldpopulation[worldpopulation['Name'].isin(specific_countries)]
# Out:
#     CCA3              Name     2022     2020     2015     2010     2000  \
# 0     CN             China  1425887  1424930  1393715  1348191  1264099
# 230   FK  Falkland Islands        4        4        3        3        3
#
#         1990    1980    1970  Area (km²)  Density (per km²)  GrowthRate  \
# 0    1153704  982372  822534     9706961           146.8933         1.0
# 230        2       2       2       12173             0.3105         1.0
#
#     World Population Percentage  Rank
# 0                        17.88%     1
# 230                       0.00%   231

# %%
#filtering based on columns using .str.constrains()
worldpopulation[worldpopulation['Name'].str.contains('Ghana')]
# Out:
#    CCA3   Name   2022   2020   2015   2010   2000   1990   1980  1970  \
# 46   GH  Ghana  33476  32180  28871  25575  19666  15447  11865  8862
#
#     Area (km²)  Density (per km²)  GrowthRate World Population Percentage  \
# 46      238533           140.3406        1.02                       0.42%
#
#     Rank
# 46    47

# %%
worldpopulation2=worldpopulation.set_index('Name')
worldpopulation2
# Out:
#                  CCA3     2022     2020     2015     2010     2000     1990  \
# Name
# China              CN  1425887  1424930  1393715  1348191  1264099  1153704
# India              IN  1417173  1396387  1322867  1240614  1059634   870452
# United States      US   338290   335942   324608   311183   282399   248084
# Indonesia          ID   275501   271858   259092   244016   214072   182160
# Pakistan           PK   235825   227197   210969   194454   154370   115414
# ...               ...      ...      ...      ...      ...      ...      ...
# Montserrat         MS        4        5        5        5        5       11
# Falkland Islands   FK        4        4        3        3        3        2
# Niue               NU        2        2        2        2        2        3
# Tokelau            TK        2        2        1        1        2        2
# Vatican City       VA        1        1        1        1        1        1
#
# ...

# %%
worldpopulation2.filter(items=['Ghana'], axis=0)
# Out:
#       CCA3   2022   2020   2015   2010   2000   1990   1980  1970  Area (km²)  \
# Name
# Ghana   GH  33476  32180  28871  25575  19666  15447  11865  8862      238533
#
#        Density (per km²)  GrowthRate World Population Percentage  Rank
# Name
# Ghana           140.3406        1.02                       0.42%    47

# %%
worldpopulation2.filter(items=['CCA3', 'World Population Percentage'], axis=1)
# Out:
#                  CCA3 World Population Percentage
# Name
# China              CN                      17.88%
# India              IN                      17.77%
# United States      US                       4.24%
# Indonesia          ID                       3.45%
# Pakistan           PK                       2.96%
# ...               ...                         ...
# Montserrat         MS                       0.00%
# Falkland Islands   FK                       0.00%
# Niue               NU                       0.00%
# Tokelau            TK                       0.00%
# Vatican City       VA                       0.00%
#
# [234 rows x 2 columns]

# %%
worldpopulation2.filter(like='United', axis=0)
# Out:
#                              CCA3    2022    2020    2015    2010    2000  \
# Name
# United States                  US  338290  335942  324608  311183  282399
# United Kingdom                 GB   67509   67059   65224   62760   58850
# United Arab Emirates           AE    9441    9287    8917    8482    3275
# United States Virgin Islands   VI      99     100     103     106     108
#
#                                 1990    1980    1970  Area (km²)  \
# Name
# United States                 248084  223140  200328     9372610
# United Kingdom                 57210   56326   55650      242900
# United Arab Emirates            1900    1014     298       83600
# United States Virgin Islands     101      97      63         347
#
#                               Density (per km²)  GrowthRate  \
# Name
# United States                           36.0935        1.00
# United Kingdom                         277.9289        1.00
# United Arab Emirates                   112.9322        1.01
# ...

# %%
#Order by
worldpopulation
# Out:
#     CCA3              Name     2022     2020     2015     2010     2000  \
# 0     CN             China  1425887  1424930  1393715  1348191  1264099
# 1     IN             India  1417173  1396387  1322867  1240614  1059634
# 2     US     United States   338290   335942   324608   311183   282399
# 3     ID         Indonesia   275501   271858   259092   244016   214072
# 4     PK          Pakistan   235825   227197   210969   194454   154370
# ..   ...               ...      ...      ...      ...      ...      ...
# 229   MS        Montserrat        4        5        5        5        5
# 230   FK  Falkland Islands        4        4        3        3        3
# 231   NU              Niue        2        2        2        2        2
# 232   TK           Tokelau        2        2        1        1        2
# 233   VA      Vatican City        1        1        1        1        1
#
#         1990    1980    1970  Area (km²)  Density (per km²)  GrowthRate  \
# ...

# %%
worldpopulation[worldpopulation['GrowthRate']<1].sort_values(by='Rank')
# Out:
#     CCA3                          Name    2022    2020    2015    2010  \
# 10    JP                         Japan  123952  125245  127251  128105
# 37    UA                       Ukraine   39702   43910   44983   45683
# 89    GR                        Greece   10385   10512   10807   11034
# 104   RS                        Serbia    7221    7358    7519    7654
# 107   BG                      Bulgaria    6782    6979    7309    7592
# 118   LB                       Lebanon    5490    5663    6399    4996
# 129   HR                       Croatia    4030    4097    4255    4369
# 136   BA        Bosnia and Herzegovina    3234    3318    3524    3811
# 140   LT                     Lithuania    2750    2820    2964    3139
# 150   LV                        Latvia    1851    1897    1992    2102
# 199   VI  United States Virgin Islands      99     100     103     106
# 212   AS                American Samoa      44      46      51      55
# ...

# %%
worldpopulation[worldpopulation['GrowthRate']<1].sort_values(by=['Name','Rank'])
# Out:
#     CCA3                          Name    2022    2020    2015    2010  \
# 212   AS                American Samoa      44      46      51      55
# 136   BA        Bosnia and Herzegovina    3234    3318    3524    3811
# 107   BG                      Bulgaria    6782    6979    7309    7592
# 129   HR                       Croatia    4030    4097    4255    4369
# 89    GR                        Greece   10385   10512   10807   11034
# 10    JP                         Japan  123952  125245  127251  128105
# 150   LV                        Latvia    1851    1897    1992    2102
# 118   LB                       Lebanon    5490    5663    6399    4996
# 140   LT                     Lithuania    2750    2820    2964    3139
# 214   MH              Marshall Islands      42      43      49      53
# 216   MC                        Monaco      36      37      37      33
# 229   MS                    Montserrat       4       5       5       5
# ...
